# %% [markdown]
# # GTFS Feed ExplorationThis notebook documents GTFS file structure and quality checks using official data artifacts and reproducible analysis steps.

# %%
from pathlib import Pathimport jsonPROJECT_ROOT = Path.cwd().resolve()print(PROJECT_ROOT)

# %%
config_path = PROJECT_ROOT / "configs" / "nyc.yaml"print(config_path.exists())print(config_path)
